# %%
import pandas as pd
import re

# %%
# Step 1: Load the text file
with open("drowned_all.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %%
# Split entries (each starts with a number and a dot)
entries = re.split(r'\n?\d{1,3}\.\s+', raw_text)
entries = [e.strip() for e in entries if e.strip()]

# %% [markdown]
# # Step 3: Define a function to extract all fields
# def extract_fields(entry):
#     date = re.search(r'(\d{1,2}/\d{2}/\d{2,4})', entry)
#     platja = re.search(r'(platja|cala|caleta|zona)[^.,\n:)]*', entry, re.IGNORECASE)
#     municipi = re.search(r'\(([^)]+)\)', entry)
#     sexe = re.search(r'\b(home|dona|nen|nena|noi|noia)\b', entry, re.IGNORECASE)
#     age = re.search(r'(\d{2,3})\s+anys', entry)
#     nationality = re.search(r'nacionalitat\s+([a-zà-ÿA-ZÀ-ß]+)|indocumentad[oa]', entry, re.IGNORECASE)
#
#     if 'no vigilad' in entry.lower() or 'servei de vigilància no havia començat' in entry.lower() or 'sense vigilància' in entry.lower():
#         surveillance = 'No'
#     elif 'vigilad' in entry.lower():
#         surveillance = 'Sí'
#     else:
#         surveillance = 'Desconegut'
#
#     if 'bandera verda' in entry.lower():
#         flag = 'Verda'
#     elif 'bandera groga' in entry.lower():
#         flag = 'Groga'
#     elif 'bandera vermella' in entry.lower():
#         flag = 'Vermella'
#     else:
#         flag = 'Desconeguda'
#
#     return {
#         "Date": date.group(1) if date else None,
#         "Platja": platja.group(0).strip() if platja else None,
#         "Municipi o comarca": municipi.group(1) if municipi else None,
#         "Sexe": sexe.group(1).lower() if sexe else None,
#         "Age": age.group(1) if age else None,
#         "Nationality or undocumented": nationality.group(1) if nationality and nationality.group(1) else "Indocumentat/da" if 'indocumentad' in entry else None,
#         "Baywatch (Surveillance)": surveillance,
#         "Flag": flag
#     }

# %% [markdown]
# def extract_platja(entry):
#     # Match "platja", "cala", or "caleta" followed by the name,
#     # stopping before words like "vigilada", "bandera", or sentence end
#     match = re.search(r'\b(platja|cala|caleta)\s+([^.,:\n()]*?)(?=\s+(vigilad|no\s*vigilad|bandera|servei|amb\s+bandera|i\s+bandera)|[.,:\n)])',
#                       entry, re.IGNORECASE)
#     if match:
#         prefix = match.group(1).capitalize()
#         name = match.group(2).strip()
#         return f"{prefix} {name}"
#     return None

# %%
def extract_platja(entry):
    # Match beach name directly after "platja", "cala", or "caleta"
    matches = re.findall(r'\b(platja|cala|caleta)\s+([^.,\n:;)]{3,50})', entry, re.IGNORECASE)
    for prefix, name in matches:
        full_name = f"{prefix.capitalize()} {name.strip()}"
        if not re.search(r'vigilad|servei de vigilància|no vigilad|sense vigilància', full_name, re.IGNORECASE):
            return full_name
    return None

# %%
def extract_fields(entry):
    date = re.search(r'(\d{1,2}/\d{2}/\d{2,4})', entry)
    platja = extract_platja(entry)
    municipi = re.search(r'\(([^)]+)\)', entry)
    sexe = re.search(r'\b(home|dona)\b', entry, re.IGNORECASE)
    age = re.search(r'(\d{2,3})\s+anys', entry)
    nationality = re.search(r'nacionalitat\s+([a-zà-ÿA-ZÀ-ÿ]+)|indocumentad[oa]', entry, re.IGNORECASE)

    if 'no vigilad' in entry.lower() or 'servei de vigilància no havia començat' in entry.lower() or 'sense vigilància' in entry.lower():
        surveillance = 'No'
    elif 'vigilad' in entry.lower():
        surveillance = 'Sí'
    else:
        surveillance = 'Desconegut'

    if 'bandera verda' in entry.lower():
        flag = 'Verda'
    elif 'bandera groga' in entry.lower():
        flag = 'Groga'
    elif 'bandera vermella' in entry.lower():
        flag = 'Vermella'
    else:
        flag = 'Desconeguda'

    return {
        "Date": date.group(1) if date else None,
        "Platja": platja,
        "Municipi o comarca": municipi.group(1) if municipi else None,
        "Sexe": sexe.group(1).capitalize() if sexe else None,
        "Age": age.group(1) if age else None,
        "Nationality or undocumented": nationality.group(1) if nationality and nationality.group(1) else ("Indocumentat/da" if 'indocumentad' in entry.lower() else None),
        "Baywatch (Surveillance)": surveillance,
        "Flag": flag,
        "Extra info": entry  # include original text for review
    }

# %%
# --- Apply to all entries ---
data = [extract_fields(entry) for entry in entries]

# %%
# --- Create DataFrame ---
df = pd.DataFrame(data)
df
# Out:
#            Date                                             Platja  \
# 0    16/06/2024                    Platja Santa Margarida de Roses
# 1    21/06/2024                     Platja de Creixell (Tarragonès
# 2    24/06/2024              Platja de la Ribera de Sitges (Garraf
# 3    25/06/2024                          Platja de la Gola del Ter
# 4    27/06/0202  Platja de Torre Valentina a Calonge i Sant Ant...
# ..          ...                                                ...
# 229  01/09/2015                                               None
# 230  01/09/2015                                               None
# 231  01/09/2015                                               None
# 232  02/09/2015                         Cala Roca Plana (Tarragona
# 233  05/09/2015                                               None
#
#     Municipi o comarca  Sexe Age Nationality or undocumented  \
# 0                 None  Home  65                   espanyola
# 1           Tarragonès  Home  77                   espanyola
# 2               Garraf  Home  55                        None
# 3         Baix Empordà  Home  74                   espanyola
# 4         Baix Empordà  Home  54                       russa
# ..                 ...   ...  ..                         ...
# 229              Roses  Home  74                    alemanya
# 230               Gavà  Home  68                   espanyola
# 231          Tarragona  Home  54                   espanyola
# 232          Tarragona  Dona  48                   espanyola
# 233       Baix Penedès  Dona  75                    alemanya
#
#     Baywatch (Surveillance)         Flag  \
# 0                Desconegut        Groga
# 1                Desconegut  Desconeguda
# 2                Desconegut  Desconeguda
# 3                        Sí        Verda
# 4                Desconegut  Desconeguda
# ..                      ...          ...
# 229                      No  Desconeguda
# 230                      Sí        Verda
# 231                      Sí  Desconeguda
# 232                      No  Desconeguda
# 233                      Sí        Groga
#
#                                             Extra info
# 0    16/06/2024: platja Santa Margarida de Roses. H...
# 1    21/06/2024: Platja de Creixell (Tarragonès). H...
# 2    24/06/2024: platja de la Ribera de Sitges (Gar...
# 3    25/06/2024: Platja de la Gola del Ter, a Torro...
# 4    27/06/02024: platja de Torre Valentina a Calon...
# ..                                                 ...
# 229  01/09/2015: Santa Margarida (Roses) (Alt Empor...
# 230  01/09/2015: Gavà (Gavà) (Baix Llobregat) Home ...
# 231  01/09/2015: Arrabassada (Tarragona) (Tarragonè...
# 232  02/09/2015: Cala Roca Plana (Tarragona) (Tarra...
# 233  05/09/2015: Calafell (Baix Penedès) Dona de na...
#
# [234 rows x 9 columns]

# %%
df['Platja']
# Out:
# 0                        Platja Santa Margarida de Roses
# 1                         Platja de Creixell (Tarragonès
# 2                  Platja de la Ribera de Sitges (Garraf
# 3                              Platja de la Gola del Ter
# 4      Platja de Torre Valentina a Calonge i Sant Ant...
#                              ...
# 229                                                 None
# 230                                                 None
# 231                                                 None
# 232                           Cala Roca Plana (Tarragona
# 233                                                 None
# Name: Platja, Length: 234, dtype: object

# %%
# Optional: export or explore
# df.to_csv("drowned_cases_cleaned.csv", index=False)
# df.head(10)

# %%
# Save to CSV
df.to_csv("drowned_cases_cleaned.csv", index=False)

# %%
from geopy.geocoders import Nominatim
import pandas as pd
# Sample data
df = pd.read_csv('drowned_cases_cleaned.csv')
geolocator = Nominatim(user_agent="ananya-geopy-lookup")
def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        return location
    except:
        return None
# Geocode each address
df['location'] = df['Platja'].apply(geocode_address)
df['latitude'] = df['location'].apply(lambda loc: loc.latitude if loc else None)
df['longitude'] = df['location'].apply(lambda loc: loc.longitude if loc else None)
df
# Out:
#            Date                                             Platja  \
# 0    16/06/2024                    platja Santa Margarida de Roses
# 1    21/06/2024                     Platja de Creixell (Tarragonès
# 2    24/06/2024              platja de la Ribera de Sitges (Garraf
# 3    25/06/2024                          Platja de la Gola del Ter
# 4    27/06/0202  platja de Torre Valentina a Calonge i Sant Ant...
# ..          ...                                                ...
# 229  01/09/2015                                 Platja no vigilada
# 230  01/09/2015                                    Platja vigilada
# 231  01/09/2015                                    Platja vigilada
# 232  02/09/2015                         Cala Roca Plana (Tarragona
# 233  05/09/2015                             Calafell (Baix Penedès
#
#     Municipi o comarca  Sexe   Age Nationality or undocumented  \
# 0                  NaN  home  65.0                   espanyola
# 1           Tarragonès  home  77.0                   espanyola
# 2               Garraf  home  55.0                         NaN
# 3         Baix Empordà  home  74.0                   espanyola
# 4         Baix Empordà  home  54.0                       russa
# ..                 ...   ...   ...                         ...
# 229              Roses  home  74.0                    alemanya
# 230               Gavà  home  68.0                   espanyola
# 231          Tarragona  home  54.0                   espanyola
# 232          Tarragona  dona  48.0                   espanyola
# 233       Baix Penedès  dona  75.0                    alemanya
#
#     Baywatch (Surveillance)         Flag  \
# 0                Desconegut        Groga
# 1                Desconegut  Desconeguda
# 2                Desconegut  Desconeguda
# 3                        Sí        Verda
# 4                Desconegut  Desconeguda
# ..                      ...          ...
# 229                      No  Desconeguda
# 230                      Sí        Verda
# 231                      Sí  Desconeguda
# 232                      No  Desconeguda
# 233                      Sí        Groga
#
#                                               location   latitude  longitude
# 0    (Platja de Sant Margarida, Santa Margarida, Ro...  42.261098   3.152984
# 1    (Platja de Creixell, el Racó del Cèsar, Creixe...  41.160646   1.454203
# 2    (Platja de la Ribera, Sitges, Garraf, Barcelon...  41.234154   1.806889
# 3                                                 None        NaN        NaN
# 4    (Via verda Platja d'Aro - Sant Antoni, Forn Ro...  41.833046   3.085585
# ..                                                 ...        ...        ...
# 229                                               None        NaN        NaN
# 230                                               None        NaN        NaN
# 231                                               None        NaN        NaN
# 232                                               None        NaN        NaN
# 233  (Calafell, Baix Penedès, Tarragona, Catalunya,...  41.201464   1.566525
#
# [234 rows x 11 columns]

# %%
# Save to new CSV
# df.to_csv("drowned_cases_geolocated.csv", index=False)
